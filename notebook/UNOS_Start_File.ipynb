# %%
import pandas as pd

# %%
STAR = pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", sheet_name= "DECEASED DONOR", header=1)

# %%
STAR
# Out:
#                     VARIABLE NAME  \
# 0                  ABN_CONGEN_DON
# 1                     ABN_LVH_DON
# 2                  ABN_VALVES_DON
# 3                         ABO_DON
# 4                  ADMIT_DATE_DON
# 5                         AGE_DON
# 6               ALCOHOL_HEAVY_DON
# 7                     AMYLASE_DON
# 8                    ANTIHYPE_DON
# 9                    ARGININE_DON
# 10             BLOOD_INF_CONF_DON
# 11                  BLOOD_INF_DON
# 12                   BMI_DON_CALC
# 13                        BUN_DON
# 14            CANCER_FREE_INT_DON
# 15           CANCER_OTH_OSTXT_DON
# 16              CARD_IDX_INIT_DON
# 17              CARD_IDX_POST_DON
# 18       CARDARREST_POSTNEURO_DON
# 19   CARDIAC_OUTPUT_CATH_INIT_DON
# 20    CARDIAC_OUTPUT_CATH_OLD_DON
# 21   CARDIAC_OUTPUT_CATH_POST_DON
# 22               CDC_RISK_HIV_DON
# 23                 CHAGAS_HISTORY
# 24                     CHAGAS_NAT
# 25                CHAGAS_SEROLOGY
# ...

# %%
STAR1=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "DECEASED DONOR", header=1)
STAR2=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "DCD INOTROPIC MEDS", header=1)
STAR3=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "KIDPAN WLHISTORY", header=1)
STAR4=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "KIDPAN DATA", header=1)
STAR5=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "KIDPAN_FORMATS_FLATFILE", header=1)
STAR6=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "KIDPAN_IMMUNO_DISCHARGE", header=1)
STAR7=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "KIDNEY FOLLOWUP", header=1)
STAR8=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "KIDPAN FOLLOWUP", header=1)
STAR9=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "PANCREAS FOLLOWUP", header=1)
STAR10=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "KIDPAN_IMMUNO_FOLLOWUP", header=1)

# %%
STAR11=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls",
                    sheet_name= "LIVER WLHISTORY", header=1)
STAR12=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVER DATA", header=1)
STAR13=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVER_IMMUNO_DISCHARGE", header=1)
STAR14=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVER EXPLANT", header=1)
STAR15=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVER_FORMATS_FLATFILE", header=1)
STAR16=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVER_IMMUNO_FOLLOWUP", header=1)
STAR17=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVER FOLLOWUP", header=1)
STAR18=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVER EXCEPTION", header=1)
STAR19=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVING DONOR", header=1)
STAR20=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVING DONOR FOLLOWUP", header=1)
STAR21=pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= "LIVING_DONOR_FORMATS_FLATFILE", header=1)

# %%
donor_sheet_names=['DECEASED DONOR','DECEASED_DONOR_FORMATS_FLATFILE','DCD INOTROPIC MEDS','Additl Deceased Donor Document']

# %%
donor_sheets={}
for sheet in donor_sheet_names:
    donor_sheets[sheet]=(pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= sheet, header=1))

# %%
len(donor_sheets)
# Out:
# 4

# %%
living_donor_sheet_names=['LIVING DONOR','LIVING DONOR FOLLOWUP','LIVING_DONOR_FORMATS_FLATFILE']

# %%
living_sheets={}
for sheet in living_donor_sheet_names:
    living_sheets[sheet] = (pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= sheet, header=1))

# %%
len(living_sheets)
# Out:
# 3

# %%
intestine_sheet_names=['INTESTINE WLHISTORY','INTESTINE IMMUNO DISCHARGE','INTESTINE FOLLOWUP',
                       'INTESTINE_IMMUNO_FOLLOWUP','INTESTINE DATA','INTESTINE_FORMATS_FLATFILE']

# %%
intestine_sheets={}
for sheet in intestine_sheet_names:
    intestine_sheets[sheet] = (pd.read_excel("/home/thesis/Downloads/STAR File Documentation.xls", 
                    sheet_name= sheet, header=1))

# %%
len(intestine_sheets)
# Out:
# 6

# %%
print(donor_sheets['DECEASED DONOR']['VARIABLE NAME'])
print(donor_sheets['DECEASED DONOR']['DATA TYPE'] )
print(donor_sheets['DECEASED DONOR']['SAS SYSTEM DATA LENGTH'])
# Out:
# 0                    ABN_CONGEN_DON
# 1                       ABN_LVH_DON
# 2                    ABN_VALVES_DON
# 3                           ABO_DON
# 4                    ADMIT_DATE_DON
# 5                           AGE_DON
# 6                 ALCOHOL_HEAVY_DON
# 7                       AMYLASE_DON
# 8                      ANTIHYPE_DON
# 9                      ARGININE_DON
# 10               BLOOD_INF_CONF_DON
# 11                    BLOOD_INF_DON
# 12                     BMI_DON_CALC
# 13                          BUN_DON
# 14              CANCER_FREE_INT_DON
# 15             CANCER_OTH_OSTXT_DON
# 16                CARD_IDX_INIT_DON
# 17                CARD_IDX_POST_DON
# 18         CARDARREST_POSTNEURO_DON
# 19     CARDIAC_OUTPUT_CATH_INIT_DON
# 20      CARDIAC_OUTPUT_CATH_OLD_DON
# 21     CARDIAC_OUTPUT_CATH_POST_DON
# 22                 CDC_RISK_HIV_DON
# 23                   CHAGAS_HISTORY
# 24                       CHAGAS_NAT
# 25                  CHAGAS_SEROLOGY
# ...

# %%
donor_sheets['DECEASED DONOR']['VARIABLE NAME'][0]
dd = donor_sheets['DECEASED DONOR']

# %%
for i in range(400):
    print(str(dd['DATA TYPE'][i])+' '+str(dd['VARIABLE NAME'][i])+' '+str(dd['SAS SYSTEM DATA LENGTH'][i]))
# Out:
# Char ABN_CONGEN_DON 1.0
# Char ABN_LVH_DON 1.0
# Char ABN_VALVES_DON 1.0
# Char ABO_DON 3.0
# Num ADMIT_DATE_DON 8.0
# Num AGE_DON 8.0
# Char ALCOHOL_HEAVY_DON 1.0
# Num AMYLASE_DON 8.0
# Char ANTIHYPE_DON 1.0
# Char ARGININE_DON 1.0
# Char BLOOD_INF_CONF_DON 1.0
# Char BLOOD_INF_DON 1.0
# Num BMI_DON_CALC 8.0
# Num BUN_DON 8.0
# Num CANCER_FREE_INT_DON 8.0
# Char CANCER_OTH_OSTXT_DON 50.0
# Num CARD_IDX_INIT_DON 8.0
# Num CARD_IDX_POST_DON 8.0
# Char CARDARREST_POSTNEURO_DON 1.0
# Num CARDIAC_OUTPUT_CATH_INIT_DON 8.0
# Num CARDIAC_OUTPUT_CATH_OLD_DON 8.0
# Num CARDIAC_OUTPUT_CATH_POST_DON 8.0
# Char CDC_RISK_HIV_DON 1.0
# Char CHAGAS_HISTORY 1.0
# Char CHAGAS_NAT 2.0
# Char CHAGAS_SEROLOGY 2.0
# Num CHEST_XRAY_DON 8.0
# Char CITIZEN_COUNTRY_DON 3.0
# Num CITIZENSHIP_DON 8.0
# Char CLIN_INFECT_DON 1.0
# Char CMV_DON 2.0
# Num COD_CAD_DON 8.0
# Char COD_OSTXT_DON 50.0
# Num CONSENT_ADVANCED_DIR 8.0
# Num CONSENT_ATTORNEY 8.0
# Char CONSENT_DOC_MECH_OSTXT 50.0
# ...
