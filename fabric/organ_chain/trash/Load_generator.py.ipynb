# %%
def create_peer_invoke_command():
    base = "docker exec -it cli peer chaincode invoke -o orderer.organ.com:7050 --tls true --cafile /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/ordererOrganizations/organ.com/orderers/orderer.organ.com/msp/tlscacerts/tlsca.organ.com-cert.pem -C organ-channel -n organcc "
    return(base)

def add_peers(org='hl', peer_n=0):
    hl_p1_add = ' --peerAddresses peer1.histocompatibility.organ.com:7051 '
    hl_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer1.histocompatibility.organ.com/tls/ca.crt '
    hl_p0_add = ' --peerAddresses peer0.histocompatibility.organ.com:7051 '
    hl_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer0.histocompatibility.organ.com/tls/ca.crt '
    
    ho_p1_add = ' --peerAddresses peer1.hospital.organ.com:7051 '
    ho_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer1.hospital.organ.com/tls/ca.crt  '
    ho_p0_add = ' --peerAddresses peer0.hospital.organ.com:7051 '
    ho_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer0.hospital.organ.com/tls/ca.crt  '
    
    gp_p1_add = ' --peerAddresses peer1.gp.organ.com:7051 '
    gp_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer1.gp.organ.com/tls/ca.crt  '
    gp_p0_add = ' --peerAddresses peer0.gp.organ.com:7051 '
    gp_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer0.gp.organ.com/tls/ca.crt  '
    
    op_p1_add = ' --peerAddresses peer1.opo.organ.com:7051 '
    op_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer1.opo.organ.com/tls/ca.crt  '
    op_p0_add = ' --peerAddresses peer0.opo.organ.com:7051 '
    op_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer0.opo.organ.com/tls/ca.crt  '
    cmd = ""
    cmd += create_peer_invoke_command() + hl_p1_add + hl_p1_cert +hl_p0_add + hl_p0_cert
    cmd += ho_p0_add + ho_p0_cert + ho_p1_add + ho_p1_cert
    cmd += gp_p0_add + gp_p0_cert + gp_p1_add + gp_p1_cert
    cmd += op_p0_add + op_p0_cert + op_p1_add + op_p1_cert
    return(cmd)

def add_organ(organ_id = '', organ_name='', organ_data=''):
    cmd = add_peers() + '-c '
    
    cmd += '\'{"Args":["initOrgan", "' + organ_id + '", "' + organ_name + '", ' + organ_data + ']}\''
    return(cmd)

def read_organ(organ_id='421'):
    cmd = add_peers()
    cmd +=  '-c \'{\"Args\":[\"readOrgan",\"' + str(organ_id) + '\"]}\''
    return(cmd)

def add_candidate(candidate_id = '', organ_name='', info=''):
    cmd = add_peers() + '-c '
    cmd += '\'{"Args":["initCandidate", "' + candidate_id + '", "' + organ_name + '", ' + info + ']}\''
    return(cmd)

def read_candidate(candidate_id='421'):
    cmd = add_peers()
    cmd +=  '-c \'{\"Args\":[\"readCandidate",\"' + str(candidate_id) + '\"]}\''
    return(cmd)

# cmd = read_organ(422)
# print(cmd)
# for i in range(10):
#     !{"echo $?" +str(i)}
# !{cmd}

# %%
def docker_cleanup():
    # !{ "docker rm -f $(docker ps -aq)"}
    # !{ "docker volume prune -f"}
    # !{ "docker network prune -f"}

# %%
with open(r"/home/thesis/Downloads/data_1.json", 'r') as file:
    data_1 = file.read()
with open(r"/home/thesis/Downloads/data_2.json", 'r') as file:
    data_2 = file.read()
with open(r"/home/thesis/Downloads/data_3.json", 'r') as file:
    data_3 = file.read()
with open(r"/home/thesis/Downloads/data_4.json", 'r') as file:
    data_4 = file.read()
    
import json
data = []
data.append(json.dumps(data_1))
data.append(json.dumps(data_2))
data.append(json.dumps(data_3))
data.append(json.dumps(data_4))

# print((data_1))

# %%
cmd = add_organ("12621", "heard", data[1])

# cmd += '\'{"Args":["initOrgan", "152", "heart", ' + data_1 + ']}\''
# cmd = read_organ(422)
# print(cmd)
# ! {cmd}

for i in range(10):
    cmd = add_organ(str(i+6000), "heard", data[i%4])
    ! {cmd}
    cmd = add_candidate(str(i+7000), "heard", data[i%4])
#     print(cmd)
    ! {cmd}
# Out:
# 2019-04-15 22:29:31.960 UTC [viperutil] getKeysRecursively -> DEBU 001 Found map[string]interface{} value for peer.BCCSP
# 2019-04-15
UTC [grpc] DialContext -> DEBU 07f parsed scheme: ""
# 2019-04-15 22:29:46.304 UTC [grpc] DialContext -> DEBU 080 scheme "" not registered, fallback to default scheme
# 2019-04-15 22:29:46.305 UTC [grpc] watcher -> DEBU 081 ccResolverWrapper: sending new addresses to cc: [{peer0.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 22:29:46.305 UTC [grpc] switchBalancer -> DEBU 082 ClientConn switching balancer to "pick_first"
# 2019-04-15 22:29:46.305 UTC [grpc] HandleSubConnStateChange -> DEBU 083 pickfirstBalancer: HandleSubConnStateChange: 0xc000541950, CONNECTING
# 2019-04-15 22:29:46.308 UTC [grpc] HandleSubConnStateChange -> DEBU 084 pickfirstBalancer: HandleSubConnStateChange: 0xc000541950, READY
# 2019-04-15 22:29:46.310 UTC [grpc] DialContext -> DEBU 085 parsed scheme: ""
# 2019-04-15 22:29:46.310 UTC [grpc] DialContext -> DEBU 086 scheme "" not registered, fallback to default scheme
# 2019-04-15 22:29:46.310 UTC [grpc] watcher -> DEBU 087 ccResolverWrapper: sending new addresses to cc: [{peer0.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 22:29:46.310 UTC [grpc] switchBalancer -> DEBU 088 ClientConn switching balancer to "pick_first"
# 2019-04-15 22:29:46.310 UTC [grpc] HandleSubConnStateChange -> DEBU 089 pickfirstBalancer: HandleSubConnStateChange: 0xc0002fc040, CONNECTING
# 2019-04-15 22:29:46.313 UTC [grpc] HandleSubConnStateChange -> DEBU 08a pickfirstBalancer: HandleSubConnStateChange: 0xc0002fc040, READY
# 2019-04-15 22:29:46.314 UTC [grpc] DialContext -> DEBU 08b parsed scheme: ""
# 2019-04-15 22:29:46.314 UTC [grpc] DialContext -> DEBU 08c scheme "" not registered, fallback to default scheme
# 2019-04-15 22:29:46.314 UTC [grpc] watcher -> DEBU 08d ccResolverWrapper: sending new addresses to cc: [{peer1.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 22:29:46.314 UTC [grpc] switchBalancer -> DEBU 08e ClientConn switching balancer to "pick_first"
# 2019-04-15 22:29:46.314 UTC [grpc] HandleSubConnStateChange -> DEBU 08f pickfirstBalancer: HandleSubConnStateChange: 0xc0003da380, CONNECTING
# 2019-04-15 22:29:46.317 UTC [grpc] HandleSubConnStateChange -> DEBU 090 pickfirstBalancer: HandleSubConnStateChange: 0xc0003da380, READY
# 2019-04-15 22:29:46.318 UTC [grpc] DialContext -> DEBU 091 parsed scheme: ""
# 2019-04-15 22:29:46.318 UTC [grpc] DialContext -> DEBU 092 scheme "" not registered, fallback to default scheme
# 2019-04-15 22:29:46.318 UTC [grpc] watcher -> DEBU 093 ccResolverWrapper: sending new addresses to cc: [{peer1.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 22:29:46.318 UTC [grpc] switchBalancer -> DEBU 094 ClientConn switching balancer to "pick_first"
# 2019-04-15 22:29:46.318 UTC [grpc] HandleSubConnStateChange -> DEBU 095 pickfirstBalancer: HandleSubConnStateChange: 0xc0006d0e60, CONNECTING
# 2019-04-15 22:29:46.321 UTC [grpc] HandleSubConnStateChange -> DEBU 096 pickfirstBalancer: HandleSubConnStateChange: 0xc0006d0e60, READY
# 2019-04-15 22:29:46.322 UTC [msp] GetDefaultSigningIdentity -> DEBU 097 Obtaining default signing identity
# 2019-04-15 22:29:46.322 UTC [grpc] DialContext -> DEBU 098 parsed scheme: ""
# 2019-04-15 22:29:46.322 UTC [grpc] DialContext -> DEBU 099 scheme "" not registered, fallback to default scheme
# 2019-04-15 22:29:46.322 UTC [grpc] watcher -> DEBU 09a ccResolverWrapper: sending new addresses to cc: [{orderer.organ.com:7050 0  <nil>}]
# 2019-04-15 22:29:46.323 UTC [grpc] switchBalancer -> DEBU 09b ClientConn switching balancer to "pick_first"
# 2019-04-15 22:29:46.323 UTC [grpc] HandleSubConnStateChange -> DEBU 09c pickfirstBalancer: HandleSubConnStateChange: 0xc0007081b0, CONNECTING
# 2019-04-15 22:29:46.326 UTC [grpc] HandleSubConnStateChange -> DEBU 09d pickfirstBalancer: HandleSubConnStateChange: 0xc0007081b0, READY
# 2019-04-15 22:29:46.329 UTC [msp.identity] Sign -> DEBU 09e Sign: plaintext: 0AD2070A6E08031A0C08DA8BD4E50510...5F4341445F444F4E223A20224346227D
# 2019-04-15 22:29:46.329 UTC [msp.identity] Sign -> DEBU 09f Sign: digest: 2AF8579D8B7C1575F4DDEF212E1657F750A08D5CB39B2D56F6C1C039148CE7B8
# 2019-04-15 22:29:46.428 UTC [msp.identity] Sign -> DEBU 0a0 Sign: plaintext: 0AD2070A6E08031A0C08DA8BD4E50510...D41B8BDAE57F4B29AF71A960415125C8
# 2019-04-15 22:29:46.428 UTC [msp.identity] Sign -> DEBU 0a1 Sign: digest: 1D8DC364E9F3344DFB4E4B2DDACA41999BFE9925AD2E64F4C21E1A940ACA5688
# 2019-04-15 22:29:46.431 UTC [chaincodeCmd] chaincodeInvokeOrQuery -> DEBU 0a2 ESCC invoke result: version:1 response:<status:200 > payload:"\n \010i1\247\252\237\te\022\323\277\206\020\004\032<%\336%\025c\235\317;\271\305\317\371\n\304 \343\022\332\205\001\n\301\205\001\022\027\n\004lscc\022\017\n\r\n\007organcc\022\002\010\005\022\244\205\001\n\007organcc\022\227\205\001\n\006\n\0047009\032\213\205\001\n\0047009\032\201\205\001{\"docType\":\"candidate\",\"candidateID\":\"7009\",\"candidateFor\":\"heard\",\"candidateInfo\":\"{\\\"num_ki_tx\\\": 50716476, \\\"pa_discard_cd_ostxt\\\": \\\"jyerjeauhdlvmqcwgcullmhlunqpdxjukrmgrfexhrupaeqxaa\\\", \\\"cardiac_output_cath_post_don\\\": 18148022, \\\"hist_oth_drug_don\\\": \\\"u\\\", \\\"kil_reason_ostxt\\\": \\\"usuafpgbhoxcfgucvtpvrycklunkhvxibbegmsmintrpgwfjox\\\", \\\"ins2_disposition\\\": 11120209, \\\"ins1_reason_cd\\\": 27140447, \\\"rt_ki_pump_ty\\\": 69574091, \\\"lis2_back_tbl_flush\\\": 15349508, \\\"pcwp_init_don\\\": 4385285, \\\"hypertens_dur_don\\\": 33255906, \\\"region\\\": 46890573, \\\"lub_discard_cd\\\": 90072075, \\\"lur_discard_cd_ostxt\\\": \\\"rhynfzjxbgsizpylsqojexafjngxkalbbjjrhidbugnazdcsqe\\\", \\\"cvp_cath_post_don\\\": 28675637, \\\"ethnicity_don\\\": 99105352, \\\"in_final_flush\\\": 86622737, \\\"pt_oth1_ostxt_don\\\": \\\"yhkczrmvdzrrcxlbgkzgzeiowyndacljdvhvdplplovymovfgxazmihbdzvoybqpagloyxlgppb\\\", \\\"hbv_dna\\\": \\\"lq\\\", \\\"pulm_inf_don\\\": 34103587, \\\"ins2_initial_flush\\\": 95101149, \\\"pt_oth2_ostxt_don\\\": \\\"ttlsrdtjfunkkiefjgekvoxipdwumuibwjsxvjzbmnsuinccnddhlhjnskbmkvcrcffkxciwptg\\\", \\\"li_reason_ostxt\\\": \\\"jinlxmjzjwabwljxfriltfpzapjzwipyxzxhxzznzsqybmdsnf\\\", \\\"ins1_back_tbl_flush_ostxt\\\": \\\"snhvmtcprszclllwxjnqzufdqyrryckbbopbymqibzfpxzboec\\\", \\\"lub_back_tbl_flush\\\": 35537223, \\\"hr_final_flush_ostxt\\\": \\\"gcbvfbflgqlaiivtinmovgrjlxnakajlcehxuznntuizjvuqyg\\\", \\\"abn_lvh_don\\\": \\\"t\\\", \\\"abn_valves_don\\\": \\\"w\\\", \\\"pas1_final_flush\\\": 21062801, \\\"pas2_disposition\\\": 51321700, \\\"kir_final_flush\\\": 58384505, \\\"citizen_country_don\\\": \\\"gbo\\\", \\\"num_li_disc\\\": 17753937, \\\"extracranial_cancer_don\\\": \\\"v\\\", \\\"ins1_discard_cd\\\": 80774236, \\\"li_reason_cd\\\": 38168555, \\\"lis2_discard_cd\\\": 45005150, \\\"kdpi\\\": 34828795, \\\"num_org_disc\\\": 68503477, \\\"po2_don\\\": 28421545, \\\"non_hrt_don\\\": \\\"p\\\", \\\"ins2_final_flush_ostxt\\\": \\\"yoklhgscimijokpcjginghkouqlgcdnxfnwgfrffvxdojnpjth\\\", \\\"li_machine_perfusion_ty\\\": 65896010, \\\"ins2_initial_flush_ostxt\\\": \\\"yvddcbhuonpfbstojgcpthuyglutjqpaixxvedqoihyldydopi\\\", \\\"admit_date_don\\\": 39249234, \\\"bmi_don_calc\\\": 28036393, \\\"intracranial_cancer_don\\\": \\\"w\\\", \\\"li_discard_cd_ostxt\\\": \\\"trcxbvdoqvmfkawhgbzepvqbbkamqhucpttryxapoxctxlrwxu\\\", \\\"map_init_don\\\": 78296540, \\\"li_initial_flush\\\": 51245474, \\\"kib_final_flush\\\": 47123277, \\\"svr_init_don\\\": 27289901, \\\"urine_inf_conf_don\\\": \\\"s\\\", \\\"li_machine_perfusion_ty_ostxt\\\": \\\"mgqgxprpzfomkqgwgmbgogvxtsmiwksznbwqqvedacxogjgvay\\\", \\\"lul_initial_flush_ostxt\\\": \\\"idkpfnkvtsjnsoaromiqyuiobdftdeueiptisnpniuaglupzxe\\\", \\\"num_li_tx\\\": 27309258, \\\"li_biopsy_don\\\": \\\"r\\\", \\\"pulm_inf_conf_don\\\": \\\"d\\\", \\\"hep_c_anti_don\\\": \\\"al\\\", \\\"pa_disposition\\\": 41618232, \\\"lur_final_flush_ostxt\\\": \\\"hotbujxjtwfglhrbmmzdjqjrgdplbwvdgshzdffhbhhcjnnilx\\\", \\\"donor_id\\\": 16397883, \\\"po2_done_don\\\": \\\"r\\\", \\\"in_reason_ostxt\\\": \\\"kojczlsenyrorruejvnxuablrmfukyosnwmpnxsxlghzmjzaka\\\", \\\"systolic_pa_cath_old_don\\\": 79206666, \\\"pa_back_tbl_flush_ostxt\\\": \\\"zdrhlghsiwvasqvadirlxgocjpzgimqqbxgblfguxlqjwoynnx\\\", \\\"num_hr_recov\\\": 94689234, \\\"macro_fat_li_don\\\": 5815344, \\\"lub_final_flush_ostxt\\\": \\\"wjlcqhhfftmjxqulecieieaovlzvutwsxkdkmwgxygvnqnicwt\\\", \\\"htlv_nat\\\": \\\"dv\\\", \\\"lub_initial_flush\\\": 74430414, \\\"in_ini ...
# 2019-04-15 22:29:46.431 UTC [chaincodeCmd] chaincodeInvokeOrQuery -> INFO 0a3 Chaincode invoke successful. result: status:200

# %%
# cmd = read_organ(1231)
! {cmd}
for i in range(10):
    cmd = read_organ(str(i+6000))
    ! {cmd}
    cmd = read_candidate(str(i+7000))
    ! {cmd}

# %%
! docker exec -it cli peer chaincode invoke -o orderer.organ.com:7050 --tls true --cafile /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/ordererOrganizations/organ.com/orderers/orderer.organ.com/msp/tlscacerts/tlsca.organ.com-cert.pem -C organ-channel -n organcc  --peerAddresses peer1.histocompatibility.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer1.histocompatibility.organ.com/tls/ca.crt  --peerAddresses peer0.histocompatibility.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer0.histocompatibility.organ.com/tls/ca.crt  --peerAddresses peer0.hospital.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer0.hospital.organ.com/tls/ca.crt   --peerAddresses peer1.hospital.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer1.hospital.organ.com/tls/ca.crt   --peerAddresses peer0.gp.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer0.gp.organ.com/tls/ca.crt   --peerAddresses peer1.gp.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer1.gp.organ.com/tls/ca.crt   --peerAddresses peer0.opo.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer0.opo.organ.com/tls/ca.crt   --peerAddresses peer1.opo.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer1.opo.organ.com/tls/ca.crt  -c '{"Args":["transferOrgan","6001", "7001"]}'

# %%
cmd = read_organ(6001)

! {cmd}

# %%
# cmd = add_candidate('Can_001', "heard", "\"This a unique Candiddate\"")
# print(cmd)
# ! {cmd}

cmd = read_candidate("7001")
print(cmd)
! {cmd}
# Out:
# docker exec -it cli peer chaincode invoke -o orderer.organ.com:7050 --tls true --cafile /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/ordererOrganizations/organ.com/orderers/orderer.organ.com/msp/tlscacerts/tlsca.organ.com-cert.pem -C organ-channel -n organcc  --peerAddresses peer1.histocompatibility.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer1.histocompatibility.organ.com/tls/ca.crt  --peerAddresses peer0.histocompatibility.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer0.histocompatibility.organ.com/tls/ca.crt  --peerAddresses peer0.hospital.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer0.hospital.organ.com/tls/ca.crt   --peerAddresses peer1.hospital.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer1.hospital.organ.com/tls/ca.crt   --peerAddresses peer0.gp.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer0.gp.organ.com/tls/ca.crt   --peerAddresses peer1.gp.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer1.gp.organ.com/tls/ca.crt   --peerAddresses peer0.opo.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer0.opo.organ.com/tls/ca.crt   --peerAddresses peer1.opo.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer1.opo.organ.com/tls/ca.crt  -c '{"Args":["readCandidate","7001"]}'
# 2019-04-15 22:30:05.799 UTC [viperutil] getKeysRecursively -> DEBU 001 Found map[string]interface{} value for peer.BCCSP
# 2019-04-15 22:30:05.799 UTC [viperutil] unmarshalJSON -> DEBU 002 Unmarshal JSON: value cannot be unmarshalled: invalid character 'S' looking for beginning of value
# 2019-04-15 22:30:05.800 UTC [viperutil] getKeysRecursively -> DEBU 003 Found real value for peer.BCCSP.Default setting to string SW
# 2019-04-15 22:30:05.800 UTC [viperutil] getKeysRecursively -> DEBU 004 Found map[string]interface{} value for peer.BCCSP.SW
# 2019-04-15 22:30:05.800 UTC [viperutil] unmarshalJSON -> DEBU 005 Unmarshal JSON: value cannot be unmarshalled: invalid character 'S' looking for beginning of value
# 2019-04-15 22:30:05.800 UTC [viperutil] getKeysRecursively -> DEBU 006 Found real value for peer.BCCSP.SW.Hash setting to string SHA2
# 2019-04-15 22:30:05.800 UTC [viperutil] unmarshalJSON -> DEBU 007 Unmarshal JSON: value is not a string: 256
# 2019-04-15 22:30:05.800 UTC [viperutil] getKeysRecursively -> DEBU 008 Found real value for peer.BCCSP.SW.Security setting to int 256
# 2019-04-15 22:30:05.801 UTC [viperutil] getKeysRecursively -> DEBU 009 Found map[string]interface{} value for peer.BCCSP.SW.FileKeyStore
# 2019-04-15 22:30:05.801 UTC [viperutil] unmarshalJSON -> DEBU 00a Unmarshal JSON: value cannot be unmarshalled: unexpected end of JSON input
# 2019-04-15 22:30:05.801 UTC [viperutil] getKeysRecursively -> DEBU 00b Found real value for peer.BCCSP.SW.FileKeyStore.KeyStore setting to string
# 2019-04-15 22:30:05.801 UTC [viperutil] getKeysRecursively -> DEBU 00c Found map[string]interface{} value for peer.BCCSP.PKCS11
# 2019-04-15 22:30:05.802 UTC [viperutil] getKeysRecursively -> DEBU 00d Found map[string]interface{} value for peer.BCCSP.PKCS11.FileKeyStore
# 2019-04-15 22:30:05.802 UTC [viperutil] unmarshalJSON -> DEBU 00e Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 22:30:05.802 UTC [viperutil] getKeysRecursively -> DEBU 00f Found real value for peer.BCCSP.PKCS11.FileKeyStore.KeyStore setting to <nil> <nil>
# 2019-04-15 22:30:05.802 UTC [viperutil] unmarshalJSON -> DEBU 010 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 22:30:05.802 UTC [viperutil] getKeysRecursively -> DEBU 011 Found real value for peer.BCCSP.PKCS11.Library setting to <nil> <nil>
# 2019-04-15 22:30:05.803 UTC [viperutil] unmarshalJSON -> DEBU 012 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 22:30:05.803 UTC [viperutil] getKeysRecursively -> DEBU 013 Found real value for peer.BCCSP.PKCS11.Label setting to <nil> <nil>
# 2019-04-15 22:30:05.803 UTC [viperutil] unmarshalJSON -> DEBU 014 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 22:30:05.803 UTC [viperutil] getKeysRecursively -> DEBU 015 Found real value for peer.BCCSP.PKCS11.Pin setting to <nil> <nil>
# 2019-04-15 22:30:05.804 UTC [viperutil] unmarshalJSON -> DEBU 016 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 22:30:05.804 UTC [viperutil] getKeysRecursively -> DEBU 017 Found real value for peer.BCCSP.PKCS11.Hash setting to <nil> <nil>
# 2019-04-15 22:30:05.804 UTC [viperutil] unmarshalJSON -> DEBU 018 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 22:30:05.804 UTC [viperutil] getKeysRecursively -> DEBU 019 Found real value for peer.BCCSP.PKCS11.Security setting to <nil> <nil>
# 2019-04-15 22:30:05.804 UTC [viperutil] EnhancedExactUnmarshalKey -> DEBU 01a map[peer.BCCSP:map[PKCS11:map[Label:<nil> Pin:<nil> Hash:<nil> Security:<nil> FileKeyStore:map[KeyStore:<nil>] Library:<n
\\", \\\"li_machine_perfusion_ty_ostxt\\\": \\\"mgqgxprpzfomkqgwgmbgogvxtsmiwksznbwqqvedacxogjgvay\\\", \\\"lul_initial_flush_ostxt\\\": \\\"idkpfnkvtsjnsoaromiqyuiobdftdeueiptisnpniuaglupzxe\\\", \\\"num_li_tx\\\": 27309258, \\\"li_biopsy_don\\\": \\\"r\\\", \\\"pulm_inf_conf_don\\\": \\\"d\\\", \\\"hep_c_anti_don\\\": \\\"al\\\", \\\"pa_disposition\\\": 41618232, \\\"lur_final_flush_ostxt\\\": \\\"hotbujxjtwfglhrbmmzdjqjrgdplbwvdgshzdffhbhhcjnnilx\\\", \\\"donor_id\\\": 16397883, \\\"po2_done_don\\\": \\\"r\\\", \\\"in_reason_ostxt\\\": \\\"kojczlsenyrorruejvnxuablrmfukyosnwmpnxsxlghzmjzaka\\\", \\\"systolic_pa_cath_old_don\\\": 79206666, \\\"pa_back_tbl_flush_ostxt\\\": \\\"zdrhlghsiwvasqvadirlxgocjpzgimqqbxgblfguxlqjwoynnx\\\", \\\"num_hr_recov\\\": 94689234, \\\"macro_fat_li_don\\\": 5815344, \\\"lub_final_flush_ostxt\\\": \\\"wjlcqhhfftmjxqulecieieaovlzvutwsxkdkmwgxygvnqnicwt\\\", \\\"htlv_nat\\\": \\\"dv\\\", \\\"lub_initial_flush\\\": 74430414, \\\"in_initial_flush\\\": 46817606, \\\"li_discard_cd\\\": 53379640, \\\"pco2_don\\\": 17063186, \\\"hba1c\\\": 63969654, \\\"lis2_final_flush_ostxt\\\": \\\"cvwfnstzaqcvayfqdywqdbtyigarykbssmxpjctmqhoujxkivi\\\", \\\"lur_discard_cd\\\": 7255450, \\\"pas1_discard_cd\\\": 67102829, \\\"pa_final_flush_ostxt\ ...

# %%
! docker exec -it cli peer chaincode invoke -o orderer.organ.com:7050 --tls true --cafile /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/ordererOrganizations/organ.com/orderers/orderer.organ.com/msp/tlscacerts/tlsca.organ.com-cert.pem -C organ-channel -n organcc  --peerAddresses peer1.histocompatibility.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer1.histocompatibility.organ.com/tls/ca.crt  --peerAddresses peer0.histocompatibility.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer0.histocompatibility.organ.com/tls/ca.crt  --peerAddresses peer0.hospital.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer0.hospital.organ.com/tls/ca.crt   --peerAddresses peer1.hospital.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer1.hospital.organ.com/tls/ca.crt   --peerAddresses peer0.gp.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer0.gp.organ.com/tls/ca.crt   --peerAddresses peer1.gp.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer1.gp.organ.com/tls/ca.crt   --peerAddresses peer0.opo.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer0.opo.organ.com/tls/ca.crt   --peerAddresses peer1.opo.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer1.opo.organ.com/tls/ca.crt  -c '{"Args":["readCandidateByMathched","5001"]}'

# %%
# !{"pwd"}
docker_cleanup()
# Out:
# /home/thesis/ocean/organ-procurement-transplant-network/fabric/organ_chain
# 95d6d313ec22
# 863e5cbf5ac1
# 0aba6cf9ad56
# 1a18b6d3bd50
# 087f34b01a36
# eb61290444db
# e2abb42e4502
# b1ca4fd7c3d2
# 92b49f351e48
# 11fd442e547c
# 3c73e094ade6
# a59828926469
# df9c0a31cc2a
# c54d910a6032
# f0689a904c4a
# b7dfa96d3005
# 82f696265dba
# 9669620b4719
# Deleted Volumes:
# experiment1_peer0.gp.organ.com
# 40419cc78575f3bfcf2567bcc4e0861b4adac80cb201f5916155292f9c3dec5f
# experiment1_peer1.opo.organ.com
# experiment1_peer1.gp.organ.com
# experiment1_orderer.organ.com
# experiment1_peer0.hospital.organ.com
# experiment1_peer1.hospital.organ.com
# experiment1_peer0.histocompatibility.organ.com
# experiment1_peer1.histocompatibility.organ.com
# experiment1_peer0.opo.organ.com
#
# Total reclaimed space: 2.552MB
# Deleted Networks:
# experiment1_organ_chain_network
